# %% [markdown]
# ## code des moyennes

# %%
# %matplotlib inline
from pylab import *
import numpy as np
x1,y1 = np.loadtxt('temp1.csv',delimiter=';', converters = {2: lambda s: float(s.strip() or 0)}, skiprows=1, usecols=(0, 1), unpack=True)
x2,y2 = np.loadtxt('temp2.csv',delimiter=';', converters = {2: lambda s: float(s.strip() or 0)}, skiprows=1, usecols=(0, 1), unpack=True)
x3,y3 = np.loadtxt('temp3.csv',delimiter=';', converters = {2: lambda s: float(s.strip() or 0)}, skiprows=1, usecols=(0, 1), unpack=True)
x4,y4 = np.loadtxt('temp4.csv',delimiter=';', converters = {2: lambda s: float(s.strip() or 0)}, skiprows=1, usecols=(0, 1), unpack=True)
x5,y5 = np.loadtxt('temp5.csv',delimiter=';', converters = {2: lambda s: float(s.strip() or 0)}, skiprows=1, usecols=(0, 1), unpack=True)
x6,y6 = np.loadtxt('temp6.csv',delimiter=';', converters = {2: lambda s: float(s.strip() or 0)}, skiprows=1, usecols=(0, 1), unpack=True)
x7,y7 = np.loadtxt('temp7.csv',delimiter=';', converters = {2: lambda s: float(s.strip() or 0)}, skiprows=1, usecols=(0, 1), unpack=True)
x8,y8 = np.loadtxt('temp8.csv',delimiter=';', converters = {2: lambda s: float(s.strip() or 0)}, skiprows=1, usecols=(0, 1), unpack=True)
x9,y9 = np.loadtxt('temp9.csv',delimiter=';', converters = {2: lambda s: float(s.strip() or 0)}, skiprows=1, usecols=(0, 1), unpack=True)
x10,y10 = np.loadtxt('temp10.csv',delimiter=';', converters = {2: lambda s: float(s.strip() or 0)}, skiprows=1, usecols=(0, 1), unpack=True)

t=[]
f=[]
m=0
n=0

for i in range (len(x1)):
    m=((x1[i]+x2[i]+x3[i]+x4[i]+x5[i]+x6[i]+x7[i]+x8[i]+x9[i]+x10[i])/10)
    f.append(m)
    
    n=((y1[i]+y2[i]+y3[i]+y4[i]+y5[i]+y6[i]+y7[i]+y8[i]+y9[i]+y10[i])/10)
    t.append(n)
    
    
    
plot(f,t, label="température en fonction de la fréquence "), 

ax= gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
legend(loc='upper left')
show()

# %%
# %matplotlib inline
from pylab import *
import numpy as np
x1,y1 = np.loadtxt('temp1.csv',delimiter=';', converters = {2: lambda s: float(s.strip() or 0)}, skiprows=1, usecols=(0, 1), unpack=True)
x2,y2 = np.loadtxt('temp2.csv',delimiter=';', converters = {2: lambda s: float(s.strip() or 0)}, skiprows=1, usecols=(0, 1), unpack=True)
x3,y3 = np.loadtxt('temp3.csv',delimiter=';', converters = {2: lambda s: float(s.strip() or 0)}, skiprows=1, usecols=(0, 1), unpack=True)
x4,y4 = np.loadtxt('temp4.csv',delimiter=';', converters = {2: lambda s: float(s.strip() or 0)}, skiprows=1, usecols=(0, 1), unpack=True)
x5,y5 = np.loadtxt('temp5.csv',delimiter=';', converters = {2: lambda s: float(s.strip() or 0)}, skiprows=1, usecols=(0, 1), unpack=True)
x6,y6 = np.loadtxt('temp6.csv',delimiter=';', converters = {2: lambda s: float(s.strip() or 0)}, skiprows=1, usecols=(0, 1), unpack=True)
x7,y7 = np.loadtxt('temp7.csv',delimiter=';', converters = {2: lambda s: float(s.strip() or 0)}, skiprows=1, usecols=(0, 1), unpack=True)
x8,y8 = np.loadtxt('temp8.csv',delimiter=';', converters = {2: lambda s: float(s.strip() or 0)}, skiprows=1, usecols=(0, 1), unpack=True)
x9,y9 = np.loadtxt('temp9.csv',delimiter=';', converters = {2: lambda s: float(s.strip() or 0)}, skiprows=1, usecols=(0, 1), unpack=True)
x10,y10 = np.loadtxt('temp10.csv',delimiter=';', converters = {2: lambda s: float(s.strip() or 0)}, skiprows=1, usecols=(0, 1), unpack=True)

t=[]
f=[]
m=0
n=0

for i in range (len(x1)):
    m=((x1[i]+x2[i]+x3[i]+x4[i]+x5[i]+x6[i]+x7[i]+x8[i]+x9[i]+x10[i])/10)
    f.append(m)
    
    n=((y1[i]+y2[i]+y3[i]+y4[i]+y5[i]+y6[i]+y7[i]+y8[i]+y9[i]+y10[i])/10)
    t.append(n)
    
    
#fonction qui retourne la moyenne de o listes
def fonction(o):
    
    t=[]
    f=[]
    m=0
    n=0
    for i in range (len(x1)):
        if o==1:
            m=((x1[i])/o)
            f.append(m)
    
            n=((y1[i]/o))
            t.append(n)
        if o==2:
            m=((x1[i]+x2[i])/o)
            f.append(m)

            n=((y1[i]+y2[i])/o)
            t.append(n)
            
        if o==3:
            m=((x1[i]+x2[i]+x3[i]/o))
            f.append(m)
    
            n=((y1[i]+y2[i]+y3[i])/o)
            t.append(n)
            
        if o==4:
            m=((x1[i]+x2[i]+x3[i]+x4[i])/o)
            f.append(m)
    
            n=((y1[i]+y2[i]+y3[i]+y4[i])/o)
            t.append(n)
            
        if o==5:
            m=((x1[i]+x2[i]+x3[i]+x4[i]+x5[i])/o)
            f.append(m)
    
            n=((y1[i]+y2[i]+y3[i]+y4[i]+y5[i])/o)
            t.append(n)
            
        if o==6:
            m=((x1[i]+x2[i]+x3[i]+x4[i]+x5[i]+x6[i]/o))
            f.append(m)
    
            n=((y1[i]+y2[i]+y3[i]+y4[i]+y5[i]+y6[i]/o))
            t.append(n)
            
        if o==7:
            m=((x1[i]+x2[i]+x3[i]+x4[i]+x5[i]+x6[i]+x7[i])/o)
            f.append(m)
    
            n=((y1[i]+y2[i]+y3[i]+y4[i]+y5[i]+y6[i]+y7[i])/o)
            t.append(n)
            
        if o==8:
            m=((x1[i]+x2[i]+x3[i]+x4[i]+x5[i]+x6[i]+x7[i]+x8[i])/o)
            f.append(m)
    
            n=((y1[i]+y2[i]+y3[i]+y4[i]+y5[i]+y6[i]+y7[i]+y8[i])/o)
            t.append(n)
            
        if o==9:
            m=((x1[i]+x2[i]+x3[i]+x4[i]+x5[i]+x6[i]+x7[i]+x8[i]+x9[i]/o))
            f.append(m)
    
            n=((y1[i]+y2[i]+y3[i]+y4[i]+y5[i]+y6[i]+y7[i]+y8[i]+y9[i]/o))
            t.append(n)
            
        if o==10:
            m=((x1[i]+x2[i]+x3[i]+x4[i]+x5[i]+x6[i]+x7[i]+x8[i]+x9[i]+x10[i])/o)
            f.append(m)
    
            n=((y1[i]+y2[i]+y3[i]+y4[i]+y5[i]+y6[i]+y7[i]+y8[i]+y9[i]+y10[i])/o)
            t.append(n)
    
    plot(f,t, label="température en fonction de la fréquence "), 

    ax= gca()
    ax.spines['right'].set_color('none')
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')
    legend(loc='upper left')
    show()

# %%
fonction(2)

# %%
fonction(9)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Python34\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     335                 pass
#     336             else:
# --> 337                 return printer(obj)
#     338             # Finally look for special method names
#     339             method = _safe_get_formatter_method(obj, self.print_method)
#
# C:\Python34\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     205
#     206     if 'png' in formats:
# --> 207         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     208     if 'retina' in formats or 'png2x' in formats:
#     209         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# C:\Python34\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     115
# ...
